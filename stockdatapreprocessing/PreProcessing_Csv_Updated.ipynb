# %%
import pandas as pd
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Set folder path
folder_path = '/content/drive/MyDrive/stock_market_data/nyse/csv/'
print("✅ Drive mounted and paths set")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Drive mounted and paths set

# %%
def clean_and_process_csv(filepath, filename, date_column='Date'):
    """Processes a single CSV file with error handling and date conversion"""
    try:
        # Read CSV with flexible parsing
        df = pd.read_csv(
            filepath,
            on_bad_lines='warn',
            dtype=str,
            encoding_errors='replace'
        )

        # Track original stats
        initial_rows = len(df)
        print(f"\n📂 Processing: {filename}")
        print(f"   Initial rows: {initial_rows:,}")

        # Check for date column and convert
        if date_column in df.columns:
            # Convert the date column to datetime, coercing errors to NaT
            df[date_column] = pd.to_datetime(df[date_column], format='%d-%m-%Y', errors='coerce')
            # Identify and report invalid dates
            invalid_dates = df[df[date_column].isna()]
            if not invalid_dates.empty:
                print(f"   ⚠️ Found {len(invalid_dates)} invalid dates in column '{date_column}'. They will be set to NaT.")

        else:
            print(f"   ⚠️ Date column '{date_column}' not found in the data.")
            return None

        # Clean the data (create new DataFrame to avoid SettingWithCopyWarning)
        clean_df = df.copy()
        clean_df = clean_df.drop_duplicates().dropna()

        # Calculate cleaning impact
        final_rows = len(clean_df)
        duplicates_removed = initial_rows - final_rows
        pct_removed = 100 * (initial_rows - final_rows) / initial_rows

        print(f"   Removed {duplicates_removed:,} rows ({pct_removed:.1f}%)")
        print(f"   Final rows: {final_rows:,}")

        # Add source filename column (properly using .loc)
        clean_df.loc[:, 'Company Symbol'] = filename.replace('.csv', '')

        return clean_df

    except Exception as e:
        print(f"\n❌ Failed to process {filename}")
        print(f"   Error: {type(e).__name__} - {str(e)}")

        # Additional error details for parsing issues
        if "Error tokenizing data" in str(e):
            error_line = str(e).split('line ')[1].split(',')[0]
            print(f"   Issue detected around line: {error_line}")

            # Show sample of problematic line
            try:
                with open(filepath, 'r') as f:
                    lines = f.readlines()
                    if int(error_line) <= len(lines):
                        print(f"   Sample of line {error_line}: {lines[int(error_line)-1][:100]}...")
            except:
                pass
        return None

# %%
all_clean_dfs = []
failed_files = []

print("🏁 Starting file processing...\n")
print("="*50)

for filename in sorted(os.listdir(folder_path)):
    if filename.endswith('.csv'):
        full_path = os.path.join(folder_path, filename)
        result = clean_and_process_csv(full_path, filename)

        if result is not None:
            all_clean_dfs.append(result)
        else:
            failed_files.append(filename)

print("\n" + "="*50)
print(f"✅ Processed {len(all_clean_dfs)} files successfully")
print(f"❌ {len(failed_files)} files had errors: {failed_files}")
# Out:
# 🏁 Starting file processing...
#
# ==================================================
#
# 📂 Processing: AAC.csv
#    Initial rows: 434
#    Removed 0 rows (0.0%)
#    Final rows: 434
#
# 📂 Processing: AAP.csv
#    Initial rows: 5,296
#    Removed 0 rows (0.0%)
#    Final rows: 5,296
#
# 📂 Processing: AAT.csv
#    Initial rows: 2,999
#    Removed 0 rows (0.0%)
#    Final rows: 2,999
#
# 📂 Processing: AB.csv
#    Initial rows: 8,736
#    Removed 0 rows (0.0%)
#    Final rows: 8,736
#
# 📂 Processing: ABC.csv
#    Initial rows: 6,973
#    Removed 0 rows (0.0%)
#    Final rows: 6,973
#
# 📂 Processing: ABG.csv
#    Initial rows: 5,220
#    Removed 0 rows (0.0%)
#    Final rows: 5,220
#
# 📂 Processing: ABM.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: ABR.csv
#    Initial rows: 4,704
#    Removed 0 rows (0.0%)
#    Final rows: 4,704
#
# 📂 Processing: ABT.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: ACG.csv
#    Initial rows: 728
#    Removed 727 rows (99.9%)
#    Final rows: 1
#
# 📂 Processing: ACGL.csv
#    Initial rows: 6,860
#    Removed 0 rows (0.0%)
#    Final rows: 6,860
#
# 📂 Processing: ACP.csv
#    Initial rows: 2,990
#    Removed 0 rows (0.0%)
#    Final rows: 2,990
#
# 📂 Processing: ACRE.csv
#    Initial rows: 2,675
#    Removed 0 rows (0.0%)
#    Final rows: 2,675
#
# 📂 Processing: ADC.csv
#    Initial rows: 7,217
#    Removed 0 rows (0.0%)
#    Final rows: 7,217
#
# 📂 Processing: ADPT.csv
#    Initial rows: 873
#    Removed 0 rows (0.0%)
#    Final rows: 873
#
# 📂 Processing: AEL.csv
#    Initial rows: 4,789
#    Removed 0 rows (0.0%)
#    Final rows: 4,789
#
# 📂 Processing: AEM.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: AEO.csv
#    Initial rows: 7,218
#    Removed 0 rows (0.0%)
#    Final rows: 7,218
#
# 📂 Processing: AEP.csv
#    Initial rows: 13,356
#    Removed 0 rows (0.0%)
#    Final rows: 13,356
#
# 📂 Processing: AER.csv
#    Initial rows: 4,042
#    Removed 0 rows (0.0%)
#    Final rows: 4,042
#
# 📂 Processing: AFB.csv
#    Initial rows: 5,256
#    Removed 0 rows (0.0%)
#    Final rows: 5,256
#
# 📂 Processing: AFG.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: AFSI.csv
#    Initial rows: 4,048
#    Removed 1,011 rows (25.0%)
#    Final rows: 3,037
#
# 📂 Processing: AFT.csv
#    Initial rows: 2,970
#    Removed 0 rows (0.0%)
#    Final rows: 2,970
#
# 📂 Processing: AG.csv
#    Initial rows: 4,038
#    Removed 0 rows (0.0%)
#    Final rows: 4,038
#
# 📂 Processing: AGD.csv
#    Initial rows: 4,124
#    Removed 0 rows (0.0%)
#    Final rows: 4,124
#
# 📂 Processing: AGI.csv
#    Initial rows: 4,939
#    Removed 0 rows (0.0%)
#    Final rows: 4,939
#
# 📂 Processing: AGM.csv
#    Initial rows: 7,261
#    Removed 0 rows (0.0%)
#    Final rows: 7,261
#
# 📂 Processing: AGO.csv
#    Initial rows: 4,693
#    Removed 0 rows (0.0%)
#    Final rows: 4,693
#
# 📂 Processing: AGRO.csv
#    Initial rows: 2,989
#    Removed 0 rows (0.0%)
#    Final rows: 2,989
#
# 📂 Processing: AHH.csv
#    Initial rows: 2,418
#    Removed 0 rows (0.0%)
#    Final rows: 2,418
#
# 📂 Processing: AHL.csv
#    Initial rows: 2,640
#    Removed 964 rows (36.5%)
#    Final rows: 1,676
#
# 📂 Processing: AHT.csv
#    Initial rows: 4,859
#    Removed 0 rows (0.0%)
#    Final rows: 4,859
#
# 📂 Processing: AI.csv
#    Initial rows: 506
#    Removed 0 rows (0.0%)
#    Final rows: 506
#
# 📂 Processing: AIF.csv
#    Initial rows: 2,468
#    Removed 0 rows (0.0%)
#    Final rows: 2,468
#
# 📂 Processing: AIG.csv
#    Initial rows: 12,598
#    Removed 0 rows (0.0%)
#    Final rows: 12,598
#
# 📂 Processing: AIT.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: AIV.csv
#    Initial rows: 7,150
#    Removed 0 rows (0.0%)
#    Final rows: 7,150
#
# 📂 Processing: AJG.csv
#    Initial rows: 9,700
#    Removed 0 rows (0.0%)
#    Final rows: 9,700
#
# 📂 Processing: AKO-A.csv
#    Initial rows: 7,161
#    Removed 0 rows (0.0%)
#    Final rows: 7,161
#
# 📂 Processing: AKR.csv
#    Initial rows: 7,441
#    Removed 0 rows (0.0%)
#    Final rows: 7,441
#
# 📂 Processing: ALEX.csv
#    Initial rows: 2,642
#    Removed 0 rows (0.0%)
#    Final rows: 2,642
#
# 📂 Processing: ALK.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: ALL.csv
#    Initial rows: 7,437
#    Removed 0 rows (0.0%)
#    Final rows: 7,437
#
# 📂 Processing: ALLE.csv
#    Initial rows: 2,283
#    Removed 0 rows (0.0%)
#    Final rows: 2,283
#
# 📂 Processing: ALLY.csv
#    Initial rows: 2,236
#    Removed 0 rows (0.0%)
#    Final rows: 2,236
#
# 📂 Processing: ALSN.csv
#    Initial rows: 2,705
#    Removed 0 rows (0.0%)
#    Final rows: 2,705
#
# 📂 Processing: AMC.csv
#    Initial rows: 2,262
#    Removed 0 rows (0.0%)
#    Final rows: 2,262
#
# 📂 Processing: AME.csv
#    Initial rows: 9,680
#    Removed 0 rows (0.0%)
#    Final rows: 9,680
#
# 📂 Processing: AMG.csv
#    Initial rows: 6,305
#    Removed 0 rows (0.0%)
#    Final rows: 6,305
#
# 📂 Processing: AMH.csv
#    Initial rows: 2,359
#    Removed 0 rows (0.0%)
#    Final rows: 2,359
#
# 📂 Processing: AMIVF.csv
#    Initial rows: 1,916
#    Removed 0 rows (0.0%)
#    Final rows: 1,916
#
# 📂 Processing: AMP.csv
#    Initial rows: 4,341
#    Removed 0 rows (0.0%)
#    Final rows: 4,341
#
# 📂 Processing: AMT.csv
#    Initial rows: 6,240
#    Removed 0 rows (0.0%)
#    Final rows: 6,240
#
# 📂 Processing: AMTD.csv
#    Initial rows: 847
#    Removed 0 rows (0.0%)
#    Final rows: 847
#
# 📂 Processing: ANET.csv
#    Initial rows: 2,146
#    Removed 0 rows (0.0%)
#    Final rows: 2,146
#
# 📂 Processing: ANF.csv
#    Initial rows: 6,598
#    Removed 0 rows (0.0%)
#    Final rows: 6,598
#
# 📂 Processing: ANR.csv
#    Initial rows: 967
#    Removed 202 rows (20.9%)
#    Final rows: 765
#
# 📂 Processing: AOD.csv
#    Initial rows: 3,940
#    Removed 0 rows (0.0%)
#    Final rows: 3,940
#
# 📂 Processing: APAM.csv
#    Initial rows: 2,461
#    Removed 0 rows (0.0%)
#    Final rows: 2,461
#
# 📂 Processing: APB.csv
#    Initial rows: 3,340
#    Removed 2,957 rows (88.5%)
#    Final rows: 383
#
# 📂 Processing: APD.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: APL.csv
#    Initial rows: 1,082
#    Removed 886 rows (81.9%)
#    Final rows: 196
#
# 📂 Processing: AR.csv
#    Initial rows: 2,310
#    Removed 0 rows (0.0%)
#    Final rows: 2,310
#
# 📂 Processing: ARAH.csv
#    Initial rows: 3,639
#    Removed 1,195 rows (32.8%)
#    Final rows: 2,444
#
# 📂 Processing: ARC.csv
#    Initial rows: 4,495
#    Removed 0 rows (0.0%)
#    Final rows: 4,495
#
# 📂 Processing: ARCC.csv
#    Initial rows: 4,580
#    Removed 0 rows (0.0%)
#    Final rows: 4,580
#
# 📂 Processing: ARCO.csv
#    Initial rows: 2,936
#    Removed 0 rows (0.0%)
#    Final rows: 2,936
#
# 📂 Processing: ARDC.csv
#    Initial rows: 2,528
#    Removed 0 rows (0.0%)
#    Final rows: 2,528
#
# 📂 Processing: ARE.csv
#    Initial rows: 6,430
#    Removed 0 rows (0.0%)
#    Final rows: 6,430
#
# 📂 Processing: ARHVF.csv
#    Initial rows: 2,880
#    Removed 0 rows (0.0%)
#    Final rows: 2,880
#
# 📂 Processing: ARI.csv
#    Initial rows: 3,328
#    Removed 0 rows (0.0%)
#    Final rows: 3,328
#
# 📂 Processing: ARL.csv
#    Initial rows: 10,249
#    Removed 0 rows (0.0%)
#    Final rows: 10,249
#
# 📂 Processing: ARR.csv
#    Initial rows: 3,784
#    Removed 0 rows (0.0%)
#    Final rows: 3,784
#
# 📂 Processing: ARW.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: ASA.csv
#    Initial rows: 11,335
#    Removed 0 rows (0.0%)
#    Final rows: 11,335
#
# 📂 Processing: ASB.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: ASC.csv
#    Initial rows: 2,359
#    Removed 0 rows (0.0%)
#    Final rows: 2,359
#
# 📂 Processing: ASGN.csv
#    Initial rows: 7,613
#    Removed 0 rows (0.0%)
#    Final rows: 7,613
#
# 📂 Processing: ASPN.csv
#    Initial rows: 2,141
#    Removed 0 rows (0.0%)
#    Final rows: 2,141
#
# 📂 Processing: ASR.csv
#    Initial rows: 5,587
#    Removed 0 rows (0.0%)
#    Final rows: 5,587
#
# 📂 Processing: ASX.csv
#    Initial rows: 5,585
#    Removed 0 rows (0.0%)
#    Final rows: 5,585
#
# 📂 Processing: ATEN.csv
#    Initial rows: 2,199
#    Removed 0 rows (0.0%)
#    Final rows: 2,199
#
# 📂 Processing: ATI.csv
#    Initial rows: 5,798
#    Removed 0 rows (0.0%)
#    Final rows: 5,798
#
# 📂 Processing: ATO.csv
#    Initial rows: 9,821
#    Removed 0 rows (0.0%)
#    Final rows: 9,821
#
# 📂 Processing: ATW.csv
#    Initial rows: 2,640
#    Removed 206 rows (7.8%)
#    Final rows: 2,434
#
# 📂 Processing: AU.csv
#    Initial rows: 6,130
#    Removed 0 rows (0.0%)
#    Final rows: 6,130
#
# 📂 Processing: AUTR.csv
#    Initial rows: 2,994
#    Removed 0 rows (0.0%)
#    Final rows: 2,994
#
# 📂 Processing: AVB.csv
#    Initial rows: 7,241
#    Removed 0 rows (0.0%)
#    Final rows: 7,241
#
# 📂 Processing: AVD.csv
#    Initial rows: 9,019
#    Removed 0 rows (0.0%)
#    Final rows: 9,019
#
# 📂 Processing: AVG.csv
#    Initial rows: 899
#    Removed 898 rows (99.9%)
#    Final rows: 1
#
# 📂 Processing: AVK.csv
#    Initial rows: 4,941
#    Removed 0 rows (0.0%)
#    Final rows: 4,941
#
# 📂 Processing: AVY.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: AWF.csv
#    Initial rows: 7,400
#    Removed 0 rows (0.0%)
#    Final rows: 7,400
#
# 📂 Processing: AWH.csv
#    Initial rows: 5,585
#    Removed 0 rows (0.0%)
#    Final rows: 5,585
#
# 📂 Processing: AWK.csv
#    Initial rows: 3,687
#    Removed 0 rows (0.0%)
#    Final rows: 3,687
#
# 📂 Processing: AWR.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: AXL.csv
#    Initial rows: 6,008
#    Removed 0 rows (0.0%)
#    Final rows: 6,008
#
# 📂 Processing: AXP.csv
#    Initial rows: 12,744
#    Removed 0 rows (0.0%)
#    Final rows: 12,744
#
# 📂 Processing: AXTA.csv
#    Initial rows: 2,035
#    Removed 0 rows (0.0%)
#    Final rows: 2,035
#
# 📂 Processing: AZN.csv
#    Initial rows: 7,452
#    Removed 0 rows (0.0%)
#    Final rows: 7,452
#
# 📂 Processing: BAH.csv
#    Initial rows: 3,037
#    Removed 0 rows (0.0%)
#    Final rows: 3,037
#
# 📂 Processing: BAK.csv
#    Initial rows: 6,019
#    Removed 0 rows (0.0%)
#    Final rows: 6,019
#
# 📂 Processing: BALT.csv
#    Initial rows: 366
#    Removed 0 rows (0.0%)
#    Final rows: 366
#
# 📂 Processing: BAM.csv
#    Initial rows: 9,819
#    Removed 0 rows (0.0%)
#    Final rows: 9,819
#
# 📂 Processing: BAP.csv
#    Initial rows: 6,831
#    Removed 0 rows (0.0%)
#    Final rows: 6,831
#
# 📂 Processing: BBVA.csv
#    Initial rows: 8,565
#    Removed 0 rows (0.0%)
#    Final rows: 8,565
#
# 📂 Processing: BCC.csv
#    Initial rows: 2,481
#    Removed 0 rows (0.0%)
#    Final rows: 2,481
#
# 📂 Processing: BCS.csv
#    Initial rows: 9,140
#    Removed 0 rows (0.0%)
#    Final rows: 9,140
#
# 📂 Processing: BCX.csv
#    Initial rows: 2,948
#    Removed 0 rows (0.0%)
#    Final rows: 2,948
#
# 📂 Processing: BDCZ.csv
#    Initial rows: 1,805
#    Removed 0 rows (0.0%)
#    Final rows: 1,805
#
# 📂 Processing: BDJ.csv
#    Initial rows: 4,352
#    Removed 0 rows (0.0%)
#    Final rows: 4,352
#
# 📂 Processing: BDN.csv
#    Initial rows: 9,172
#    Removed 0 rows (0.0%)
#    Final rows: 9,172
#
# 📂 Processing: BDX.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: BEN.csv
#    Initial rows: 9,887
#    Removed 0 rows (0.0%)
#    Final rows: 9,887
#
# 📂 Processing: BEP.csv
#    Initial rows: 4,298
#    Removed 0 rows (0.0%)
#    Final rows: 4,298
#
# 📂 Processing: BERY.csv
#    Initial rows: 2,564
#    Removed 0 rows (0.0%)
#    Final rows: 2,564
#
# 📂 Processing: BFAM.csv
#    Initial rows: 2,489
#    Removed 0 rows (0.0%)
#    Final rows: 2,489
#
# 📂 Processing: BFK.csv
#    Initial rows: 5,379
#    Removed 0 rows (0.0%)
#    Final rows: 5,379
#
# 📂 Processing: BFZ.csv
#    Initial rows: 5,379
#    Removed 0 rows (0.0%)
#    Final rows: 5,379
#
# 📂 Processing: BG.csv
#    Initial rows: 5,375
#    Removed 0 rows (0.0%)
#    Final rows: 5,375
#
# 📂 Processing: BGB.csv
#    Initial rows: 2,570
#    Removed 0 rows (0.0%)
#    Final rows: 2,570
#
# 📂 Processing: BGC.csv
#    Initial rows: 1,204
#    Removed 25 rows (2.1%)
#    Final rows: 1,179
#
# 📂 Processing: BGR.csv
#    Initial rows: 4,524
#    Removed 0 rows (0.0%)
#    Final rows: 4,524
#
# 📂 Processing: BGT.csv
#    Initial rows: 4,605
#    Removed 0 rows (0.0%)
#    Final rows: 4,605
#
# 📂 Processing: BGX.csv
#    Initial rows: 2,990
#    Removed 0 rows (0.0%)
#    Final rows: 2,990
#
# 📂 Processing: BH.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: BHE.csv
#    Initial rows: 8,179
#    Removed 0 rows (0.0%)
#    Final rows: 8,179
#
# 📂 Processing: BHI.csv
#    Initial rows: 1,081
#    Removed 887 rows (82.1%)
#    Final rows: 194
#
# 📂 Processing: BHK.csv
#    Initial rows: 5,297
#    Removed 0 rows (0.0%)
#    Final rows: 5,297
#
# 📂 Processing: BHL.csv
#    Initial rows: 2,640
#    Removed 207 rows (7.8%)
#    Final rows: 2,433
#
# 📂 Processing: BHLB.csv
#    Initial rows: 5,651
#    Removed 0 rows (0.0%)
#    Final rows: 5,651
#
# 📂 Processing: BHP.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: BIN.csv
#    Initial rows: 1,577
#    Removed 1,181 rows (74.9%)
#    Final rows: 396
#
# 📂 Processing: BIP.csv
#    Initial rows: 3,758
#    Removed 0 rows (0.0%)
#    Final rows: 3,758
#
# 📂 Processing: BJZ.csv
#    Initial rows: 3,340
#    Removed 2,964 rows (88.7%)
#    Final rows: 376
#
# 📂 Processing: BK.csv
#    Initial rows: 12,514
#    Removed 0 rows (0.0%)
#    Final rows: 12,514
#
# 📂 Processing: BKD.csv
#    Initial rows: 4,293
#    Removed 0 rows (0.0%)
#    Final rows: 4,293
# /tmp/ipython-input-28-1816639542.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.loc[:, 'Company Symbol'] = filename.replace('.csv', '')
# 📂 Processing: BKN.csv
#    Initial rows: 7,509
#    Removed 0 rows (0.0%)
#    Final rows: 7,509
#
# 📂 Processing: BKT.csv
#    Initial rows: 8,667
#    Removed 0 rows (0.0%)
#    Final rows: 8,667
#
# 📂 Processing: BLH.csv
#    Initial rows: 3,340
#    Removed 2,965 rows (88.8%)
#    Final rows: 375
#
# 📂 Processing: BLK.csv
#    Initial rows: 5,838
#    Removed 0 rows (0.0%)
#    Final rows: 5,838
#
# 📂 Processing: BLW.csv
#    Initial rows: 4,879
#    Removed 0 rows (0.0%)
#    Final rows: 4,879
#
# 📂 Processing: BLX.csv
#    Initial rows: 7,611
#    Removed 0 rows (0.0%)
#    Final rows: 7,611
#
# 📂 Processing: BME.csv
#    Initial rows: 4,460
#    Removed 0 rows (0.0%)
#    Final rows: 4,460
#
# 📂 Processing: BMO.csv
#    Initial rows: 7,082
#    Removed 0 rows (0.0%)
#    Final rows: 7,082
#
# 📂 Processing: BMS.csv
#    Initial rows: 12,742
#    Removed 1,019 rows (8.0%)
#    Final rows: 11,723
#
# 📂 Processing: BNCM.csv
#    Initial rows: 6,732
#    Removed 16 rows (0.2%)
#    Final rows: 6,716
#
# 📂 Processing: BNJ.csv
#    Initial rows: 3,340
#    Removed 3,108 rows (93.1%)
#    Final rows: 232
#
# 📂 Processing: BNK.csv
#    Initial rows: 924
#    Removed 811 rows (87.8%)
#    Final rows: 113
#
# 📂 Processing: BNY.csv
#    Initial rows: 5,379
#    Removed 0 rows (0.0%)
#    Final rows: 5,379
#
# 📂 Processing: BOH.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: BOOT.csv
#    Initial rows: 2,044
#    Removed 0 rows (0.0%)
#    Final rows: 2,044
#
# 📂 Processing: BPK.csv
#    Initial rows: 3,340
#    Removed 2,964 rows (88.7%)
#    Final rows: 376
#
# 📂 Processing: BPT.csv
#    Initial rows: 8,456
#    Removed 0 rows (0.0%)
#    Final rows: 8,456
#
# 📂 Processing: BR.csv
#    Initial rows: 3,961
#    Removed 0 rows (0.0%)
#    Final rows: 3,961
#
# 📂 Processing: BRFS.csv
#    Initial rows: 5,571
#    Removed 0 rows (0.0%)
#    Final rows: 5,571
#
# 📂 Processing: BRK-A.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: BRO.csv
#    Initial rows: 10,549
#    Removed 0 rows (0.0%)
#    Final rows: 10,549
#
# 📂 Processing: BRP.csv
#    Initial rows: 790
#    Removed 0 rows (0.0%)
#    Final rows: 790
#
# 📂 Processing: BRX.csv
#    Initial rows: 2,296
#    Removed 0 rows (0.0%)
#    Final rows: 2,296
#
# 📂 Processing: BSAC.csv
#    Initial rows: 7,080
#    Removed 0 rows (0.0%)
#    Final rows: 7,080
#
# 📂 Processing: BSI.csv
#    Initial rows: 2,868
#    Removed 305 rows (10.6%)
#    Final rows: 2,563
#
# 📂 Processing: BSL.csv
#    Initial rows: 3,160
#    Removed 0 rows (0.0%)
#    Final rows: 3,160
#
# 📂 Processing: BST.csv
#    Initial rows: 2,045
#    Removed 0 rows (0.0%)
#    Final rows: 2,045
#
# 📂 Processing: BSX.csv
#    Initial rows: 7,700
#    Removed 0 rows (0.0%)
#    Final rows: 7,700
#
# 📂 Processing: BTF.csv
#    Initial rows: 287
#    Removed 0 rows (0.0%)
#    Final rows: 287
#
# 📂 Processing: BTO.csv
#    Initial rows: 7,133
#    Removed 0 rows (0.0%)
#    Final rows: 7,133
#
# 📂 Processing: BTSGY.csv
#    Initial rows: 2,306
#    Removed 0 rows (0.0%)
#    Final rows: 2,306
#
# 📂 Processing: BTU.csv
#    Initial rows: 1,435
#    Removed 0 rows (0.0%)
#    Final rows: 1,435
#
# 📂 Processing: BTZ.csv
#    Initial rows: 4,020
#    Removed 0 rows (0.0%)
#    Final rows: 4,020
#
# 📂 Processing: BUI.csv
#    Initial rows: 2,781
#    Removed 0 rows (0.0%)
#    Final rows: 2,781
#
# 📂 Processing: BURL.csv
#    Initial rows: 2,316
#    Removed 0 rows (0.0%)
#    Final rows: 2,316
#
# 📂 Processing: BWG.csv
#    Initial rows: 2,696
#    Removed 0 rows (0.0%)
#    Final rows: 2,696
#
# 📂 Processing: BWMG.csv
#    Initial rows: 6,155
#    Removed 392 rows (6.4%)
#    Final rows: 5,763
#
# 📂 Processing: BWP.csv
#    Initial rows: 4,302
#    Removed 1,110 rows (25.8%)
#    Final rows: 3,192
#
# 📂 Processing: BXC.csv
#    Initial rows: 4,531
#    Removed 0 rows (0.0%)
#    Final rows: 4,531
#
# 📂 Processing: BXMT.csv
#    Initial rows: 10,580
#    Removed 0 rows (0.0%)
#    Final rows: 10,580
#
# 📂 Processing: BXMX.csv
#    Initial rows: 4,564
#    Removed 0 rows (0.0%)
#    Final rows: 4,564
#
# 📂 Processing: BXP.csv
#    Initial rows: 6,415
#    Removed 0 rows (0.0%)
#    Final rows: 6,415
#
# 📂 Processing: BYM.csv
#    Initial rows: 5,066
#    Removed 0 rows (0.0%)
#    Final rows: 5,066
#
# 📂 Processing: BZH.csv
#    Initial rows: 7,253
#    Removed 0 rows (0.0%)
#    Final rows: 7,253
#
# 📂 Processing: C-PK.csv
#    Initial rows: 2,298
#    Removed 0 rows (0.0%)
#    Final rows: 2,298
#
# 📂 Processing: CAF.csv
#    Initial rows: 4,080
#    Removed 0 rows (0.0%)
#    Final rows: 4,080
#
# 📂 Processing: CAH.csv
#    Initial rows: 9,922
#    Removed 0 rows (0.0%)
#    Final rows: 9,922
#
# 📂 Processing: CBA.csv
#    Initial rows: 2,378
#    Removed 47 rows (2.0%)
#    Final rows: 2,331
#
# 📂 Processing: CBD.csv
#    Initial rows: 6,738
#    Removed 0 rows (0.0%)
#    Final rows: 6,738
#
# 📂 Processing: CBI.csv
#    Initial rows: 4,364
#    Removed 88 rows (2.0%)
#    Final rows: 4,276
#
# 📂 Processing: CBL.csv
#    Initial rows: 280
#    Removed 0 rows (0.0%)
#    Final rows: 280
#
# 📂 Processing: CBU.csv
#    Initial rows: 9,337
#    Removed 0 rows (0.0%)
#    Final rows: 9,337
#
# 📂 Processing: CCI.csv
#    Initial rows: 6,121
#    Removed 0 rows (0.0%)
#    Final rows: 6,121
#
# 📂 Processing: CCK.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: CCM.csv
#    Initial rows: 3,273
#    Removed 0 rows (0.0%)
#    Final rows: 3,273
#
# 📂 Processing: CCS.csv
#    Initial rows: 2,138
#    Removed 0 rows (0.0%)
#    Final rows: 2,138
#
# 📂 Processing: CCU.csv
#    Initial rows: 7,611
#    Removed 0 rows (0.0%)
#    Final rows: 7,611
#
# 📂 Processing: CCZ.csv
#    Initial rows: 730
#    Removed 0 rows (0.0%)
#    Final rows: 730
#
# 📂 Processing: CEA.csv
#    Initial rows: 6,508
#    Removed 0 rows (0.0%)
#    Final rows: 6,508
#
# 📂 Processing: CEE.csv
#    Initial rows: 8,262
#    Removed 0 rows (0.0%)
#    Final rows: 8,262
#
# 📂 Processing: CEM.csv
#    Initial rows: 3,139
#    Removed 0 rows (0.0%)
#    Final rows: 3,139
#
# 📂 Processing: CEN.csv
#    Initial rows: 2,320
#    Removed 0 rows (0.0%)
#    Final rows: 2,320
#
# 📂 Processing: CEO.csv
#    Initial rows: 5,483
#    Removed 390 rows (7.1%)
#    Final rows: 5,093
#
# 📂 Processing: CEQP.csv
#    Initial rows: 5,380
#    Removed 0 rows (0.0%)
#    Final rows: 5,380
#
# 📂 Processing: CF.csv
#    Initial rows: 4,365
#    Removed 0 rows (0.0%)
#    Final rows: 4,365
#
# 📂 Processing: CFG.csv
#    Initial rows: 2,070
#    Removed 0 rows (0.0%)
#    Final rows: 2,070
#
# 📂 Processing: CFR.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: CGA.csv
#    Initial rows: 3,692
#    Removed 0 rows (0.0%)
#    Final rows: 3,692
#
# 📂 Processing: CHCO.csv
#    Initial rows: 8,938
#    Removed 0 rows (0.0%)
#    Final rows: 8,938
#
# 📂 Processing: CHD.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: CHE.csv
#    Initial rows: 12,514
#    Removed 0 rows (0.0%)
#    Final rows: 12,514
#
# 📂 Processing: CHH.csv
#    Initial rows: 6,584
#    Removed 0 rows (0.0%)
#    Final rows: 6,584
#
# 📂 Processing: CHMI.csv
#    Initial rows: 2,314
#    Removed 0 rows (0.0%)
#    Final rows: 2,314
#
# 📂 Processing: CHNR.csv
#    Initial rows: 6,887
#    Removed 0 rows (0.0%)
#    Final rows: 6,887
#
# 📂 Processing: CHS.csv
#    Initial rows: 7,486
#    Removed 0 rows (0.0%)
#    Final rows: 7,486
#
# 📂 Processing: CHT.csv
#    Initial rows: 4,886
#    Removed 0 rows (0.0%)
#    Final rows: 4,886
#
# 📂 Processing: CIB.csv
#    Initial rows: 6,895
#    Removed 0 rows (0.0%)
#    Final rows: 6,895
#
# 📂 Processing: CIF.csv
#    Initial rows: 8,667
#    Removed 0 rows (0.0%)
#    Final rows: 8,667
#
# 📂 Processing: CII.csv
#    Initial rows: 4,670
#    Removed 0 rows (0.0%)
#    Final rows: 4,670
#
# 📂 Processing: CIM.csv
#    Initial rows: 3,786
#    Removed 0 rows (0.0%)
#    Final rows: 3,786
#
# 📂 Processing: CIO.csv
#    Initial rows: 2,182
#    Removed 0 rows (0.0%)
#    Final rows: 2,182
#
# 📂 Processing: CIR.csv
#    Initial rows: 5,827
#    Removed 0 rows (0.0%)
#    Final rows: 5,827
#
# 📂 Processing: CIVI.csv
#    Initial rows: 2,766
#    Removed 0 rows (0.0%)
#    Final rows: 2,766
#
# 📂 Processing: CLB.csv
#    Initial rows: 6,855
#    Removed 0 rows (0.0%)
#    Final rows: 6,855
#
# 📂 Processing: CLH.csv
#    Initial rows: 8,833
#    Removed 0 rows (0.0%)
#    Final rows: 8,833
#
# 📂 Processing: CLR.csv
#    Initial rows: 3,923
#    Removed 12 rows (0.3%)
#    Final rows: 3,911
#
# 📂 Processing: CLW.csv
#    Initial rows: 3,529
#    Removed 0 rows (0.0%)
#    Final rows: 3,529
#
# 📂 Processing: CM.csv
#    Initial rows: 6,311
#    Removed 0 rows (0.0%)
#    Final rows: 6,311
#
# 📂 Processing: CMC.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: CMCSA.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: CMG.csv
#    Initial rows: 4,250
#    Removed 0 rows (0.0%)
#    Final rows: 4,250
#
# 📂 Processing: CMP.csv
#    Initial rows: 4,783
#    Removed 0 rows (0.0%)
#    Final rows: 4,783
#
# 📂 Processing: CMS.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: CNHI.csv
#    Initial rows: 2,318
#    Removed 0 rows (0.0%)
#    Final rows: 2,318
#
# 📂 Processing: CNI.csv
#    Initial rows: 6,555
#    Removed 0 rows (0.0%)
#    Final rows: 6,555
#
# 📂 Processing: CNO.csv
#    Initial rows: 4,849
#    Removed 0 rows (0.0%)
#    Final rows: 4,849
#
# 📂 Processing: CNP.csv
#    Initial rows: 13,356
#    Removed 0 rows (0.0%)
#    Final rows: 13,356
#
# 📂 Processing: CNQ.csv
#    Initial rows: 5,629
#    Removed 0 rows (0.0%)
#    Final rows: 5,629
#
# 📂 Processing: CNS.csv
#    Initial rows: 4,615
#    Removed 0 rows (0.0%)
#    Final rows: 4,615
#
# 📂 Processing: CNX.csv
#    Initial rows: 5,945
#    Removed 0 rows (0.0%)
#    Final rows: 5,945
#
# 📂 Processing: CO.csv
#    Initial rows: 3,928
#    Removed 0 rows (0.0%)
#    Final rows: 3,928
#
# 📂 Processing: CODI.csv
#    Initial rows: 4,172
#    Removed 0 rows (0.0%)
#    Final rows: 4,172
#
# 📂 Processing: COF.csv
#    Initial rows: 7,068
#    Removed 0 rows (0.0%)
#    Final rows: 7,068
#
# 📂 Processing: COL.csv
#    Initial rows: 2,608
#    Removed 549 rows (21.1%)
#    Final rows: 2,059
#
# 📂 Processing: COP.csv
#    Initial rows: 10,325
#    Removed 0 rows (0.0%)
#    Final rows: 10,325
#
# 📂 Processing: CORR.csv
#    Initial rows: 3,994
#    Removed 0 rows (0.0%)
#    Final rows: 3,994
#
# 📂 Processing: CP.csv
#    Initial rows: 9,819
#    Removed 0 rows (0.0%)
#    Final rows: 9,819
#
# 📂 Processing: CPB.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: CPE.csv
#    Initial rows: 8,244
#    Removed 0 rows (0.0%)
#    Final rows: 8,244
#
# 📂 Processing: CPF.csv
#    Initial rows: 8,894
#    Removed 0 rows (0.0%)
#    Final rows: 8,894
#
# 📂 Processing: CPG.csv
#    Initial rows: 4,821
#    Removed 0 rows (0.0%)
#    Final rows: 4,821
#
# 📂 Processing: CPK.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: CPT.csv
#    Initial rows: 7,403
#    Removed 0 rows (0.0%)
#    Final rows: 7,403
#
# 📂 Processing: CRC.csv
#    Initial rows: 535
#    Removed 0 rows (0.0%)
#    Final rows: 535
#
# 📂 Processing: CRD-B.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: CRK.csv
#    Initial rows: 8,894
#    Removed 0 rows (0.0%)
#    Final rows: 8,894
#
# 📂 Processing: CRL.csv
#    Initial rows: 5,654
#    Removed 0 rows (0.0%)
#    Final rows: 5,654
#
# 📂 Processing: CRS.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: CRT.csv
#    Initial rows: 7,756
#    Removed 0 rows (0.0%)
#    Final rows: 7,756
#
# 📂 Processing: CS.csv
#    Initial rows: 6,944
#    Removed 0 rows (0.0%)
#    Final rows: 6,944
#
# 📂 Processing: CSC.csv
#    Initial rows: 2,640
#    Removed 322 rows (12.2%)
#    Final rows: 2,318
#
# 📂 Processing: CSH.csv
#    Initial rows: 218
#    Removed 0 rows (0.0%)
#    Final rows: 218
#
# 📂 Processing: CSL.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: CSTM.csv
#    Initial rows: 2,407
#    Removed 0 rows (0.0%)
#    Final rows: 2,407
#
# 📂 Processing: CSV.csv
#    Initial rows: 6,631
#    Removed 0 rows (0.0%)
#    Final rows: 6,631
#
# 📂 Processing: CTR.csv
#    Initial rows: 2,607
#    Removed 0 rows (0.0%)
#    Final rows: 2,607
#
# 📂 Processing: CUBI.csv
#    Initial rows: 2,706
#    Removed 0 rows (0.0%)
#    Final rows: 2,706
#
# 📂 Processing: CUDA.csv
#    Initial rows: 2,291
#    Removed 263 rows (11.5%)
#    Final rows: 2,028
#
# 📂 Processing: CUK.csv
#    Initial rows: 5,570
#    Removed 0 rows (0.0%)
#    Final rows: 5,570
#
# 📂 Processing: CUPUF.csv
#    Initial rows: 3,527
#    Removed 0 rows (0.0%)
#    Final rows: 3,527
#
# 📂 Processing: CUZ.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: CVE.csv
#    Initial rows: 3,290
#    Removed 0 rows (0.0%)
#    Final rows: 3,290
#
# 📂 Processing: CWT.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: CXE.csv
#    Initial rows: 8,521
#    Removed 0 rows (0.0%)
#    Final rows: 8,521
#
# 📂 Processing: CXH.csv
#    Initial rows: 8,458
#    Removed 0 rows (0.0%)
#    Final rows: 8,458
#
# 📂 Processing: CYD.csv
#    Initial rows: 7,047
#    Removed 0 rows (0.0%)
#    Final rows: 7,047
#
# 📂 Processing: CYH.csv
#    Initial rows: 5,664
#    Removed 0 rows (0.0%)
#    Final rows: 5,664
#
# 📂 Processing: CYS.csv
#    Initial rows: 3,400
#    Removed 1,100 rows (32.4%)
#    Final rows: 2,300
#
# 📂 Processing: DAL.csv
#    Initial rows: 3,932
#    Removed 0 rows (0.0%)
#    Final rows: 3,932
#
# 📂 Processing: DAR.csv
#    Initial rows: 7,116
#    Removed 0 rows (0.0%)
#    Final rows: 7,116
#
# 📂 Processing: DBL.csv
#    Initial rows: 2,738
#    Removed 0 rows (0.0%)
#    Final rows: 2,738
#
# 📂 Processing: DCI.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: DCO.csv
#    Initial rows: 12,514
#    Removed 0 rows (0.0%)
#    Final rows: 12,514
#
# 📂 Processing: DCT.csv
#    Initial rows: 587
#    Removed 0 rows (0.0%)
#    Final rows: 587
#
# 📂 Processing: DD.csv
#    Initial rows: 12,744
#    Removed 0 rows (0.0%)
#    Final rows: 12,744
#
# 📂 Processing: DDF.csv
#    Initial rows: 7,489
#    Removed 0 rows (0.0%)
#    Final rows: 7,489
#
# 📂 Processing: DDS.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: DDT.csv
#    Initial rows: 6,081
#    Removed 0 rows (0.0%)
#    Final rows: 6,081
#
# 📂 Processing: DE.csv
#    Initial rows: 12,744
#    Removed 0 rows (0.0%)
#    Final rows: 12,744
#
# 📂 Processing: DECK.csv
#    Initial rows: 7,343
#    Removed 0 rows (0.0%)
#    Final rows: 7,343
#
# 📂 Processing: DEI.csv
#    Initial rows: 4,061
#    Removed 0 rows (0.0%)
#    Final rows: 4,061
#
# 📂 Processing: DEL.csv
#    Initial rows: 6,544
#    Removed 1,221 rows (18.7%)
#    Final rows: 5,323
#
# 📂 Processing: DEX.csv
#    Initial rows: 3,874
#    Removed 0 rows (0.0%)
#    Final rows: 3,874
#
# 📂 Processing: DFS.csv
#    Initial rows: 3,903
#    Removed 0 rows (0.0%)
#    Final rows: 3,903
#
# 📂 Processing: DG.csv
#    Initial rows: 3,292
#    Removed 0 rows (0.0%)
#    Final rows: 3,292
#
# 📂 Processing: DGX.csv
#    Initial rows: 6,541
#    Removed 0 rows (0.0%)
#    Final rows: 6,541
#
# 📂 Processing: DHF.csv
#    Initial rows: 6,200
#    Removed 0 rows (0.0%)
#    Final rows: 6,200
#
# 📂 Processing: DHG.csv
#    Initial rows: 1,316
#    Removed 1,193 rows (90.7%)
#    Final rows: 123
#
# 📂 Processing: DHI.csv
#    Initial rows: 7,688
#    Removed 0 rows (0.0%)
#    Final rows: 7,688
#
# 📂 Processing: DHT.csv
#    Initial rows: 4,321
#    Removed 0 rows (0.0%)
#    Final rows: 4,321
#
# 📂 Processing: DIAX.csv
#    Initial rows: 2,021
#    Removed 0 rows (0.0%)
#    Final rows: 2,021
#
# 📂 Processing: DK.csv
#    Initial rows: 4,182
#    Removed 0 rows (0.0%)
#    Final rows: 4,182
#
# 📂 Processing: DKS.csv
#    Initial rows: 5,075
#    Removed 0 rows (0.0%)
#    Final rows: 5,075
#
# 📂 Processing: DLB.csv
#    Initial rows: 4,486
#    Removed 0 rows (0.0%)
#    Final rows: 4,486
#
# 📂 Processing: DLNG.csv
#    Initial rows: 2,286
#    Removed 0 rows (0.0%)
#    Final rows: 2,286
#
# 📂 Processing: DLR.csv
#    Initial rows: 4,562
#    Removed 0 rows (0.0%)
#    Final rows: 4,562
#
# 📂 Processing: DMB.csv
#    Initial rows: 2,426
#    Removed 0 rows (0.0%)
#    Final rows: 2,426
#
# 📂 Processing: DMO.csv
#    Initial rows: 3,224
#    Removed 0 rows (0.0%)
#    Final rows: 3,224
#
# 📂 Processing: DNB.csv
#    Initial rows: 618
#    Removed 0 rows (0.0%)
#    Final rows: 618
#
# 📂 Processing: DNP.csv
#    Initial rows: 9,047
#    Removed 0 rows (0.0%)
#    Final rows: 9,047
#
# 📂 Processing: DO.csv
#    Initial rows: 178
#    Removed 0 rows (0.0%)
#    Final rows: 178
#
# 📂 Processing: DOMR.csv
#    Initial rows: 7,172
#    Removed 7 rows (0.1%)
#    Final rows: 7,165
#
# 📂 Processing: DOOR.csv
#    Initial rows: 3,371
#    Removed 0 rows (0.0%)
#    Final rows: 3,371
#
# 📂 Processing: DPG.csv
#    Initial rows: 2,862
#    Removed 0 rows (0.0%)
#    Final rows: 2,862
#
# 📂 Processing: DPSGY.csv
#    Initial rows: 3,505
#    Removed 0 rows (0.0%)
#    Final rows: 3,505
#
# 📂 Processing: DPZ.csv
#    Initial rows: 4,639
#    Removed 0 rows (0.0%)
#    Final rows: 4,639
#
# 📂 Processing: DRH.csv
#    Initial rows: 4,418
#    Removed 0 rows (0.0%)
#    Final rows: 4,418
#
# 📂 Processing: DRI.csv
#    Initial rows: 6,949
#    Removed 0 rows (0.0%)
#    Final rows: 6,949
#
# 📂 Processing: DRLCQ.csv
#    Initial rows: 8,563
#    Removed 1,075 rows (12.6%)
#    Final rows: 7,488
#
# 📂 Processing: DSL.csv
#    Initial rows: 2,426
#    Removed 0 rows (0.0%)
#    Final rows: 2,426
#
# 📂 Processing: DSM.csv
#    Initial rows: 8,328
# /tmp/ipython-input-28-1816639542.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.loc[:, 'Company Symbol'] = filename.replace('.csv', '')
#    Removed 0 rows (0.0%)
#    Final rows: 8,328
#
# 📂 Processing: DST.csv
#    Initial rows: 6,826
#    Removed 1,184 rows (17.3%)
#    Final rows: 5,642
#
# 📂 Processing: DSU.csv
#    Initial rows: 6,219
#    Removed 0 rows (0.0%)
#    Final rows: 6,219
#
# 📂 Processing: DSX.csv
#    Initial rows: 4,463
#    Removed 0 rows (0.0%)
#    Final rows: 4,463
#
# 📂 Processing: DTE.csv
#    Initial rows: 13,356
#    Removed 0 rows (0.0%)
#    Final rows: 13,356
#
# 📂 Processing: DTK.csv
#    Initial rows: 3,723
#    Removed 1,214 rows (32.6%)
#    Final rows: 2,509
#
# 📂 Processing: DV.csv
#    Initial rows: 416
#    Removed 0 rows (0.0%)
#    Final rows: 416
#
# 📂 Processing: DVN.csv
#    Initial rows: 9,426
#    Removed 0 rows (0.0%)
#    Final rows: 9,426
#
# 📂 Processing: DX.csv
#    Initial rows: 8,780
#    Removed 0 rows (0.0%)
#    Final rows: 8,780
#
# 📂 Processing: DY.csv
#    Initial rows: 9,712
#    Removed 0 rows (0.0%)
#    Final rows: 9,712
#
# 📂 Processing: EARN.csv
#    Initial rows: 2,423
#    Removed 0 rows (0.0%)
#    Final rows: 2,423
#
# 📂 Processing: EAT.csv
#    Initial rows: 9,815
#    Removed 0 rows (0.0%)
#    Final rows: 9,815
#
# 📂 Processing: EBS.csv
#    Initial rows: 4,046
#    Removed 0 rows (0.0%)
#    Final rows: 4,046
#
# 📂 Processing: ED.csv
#    Initial rows: 13,356
#    Removed 0 rows (0.0%)
#    Final rows: 13,356
#
# 📂 Processing: EDD.csv
#    Initial rows: 3,939
#    Removed 0 rows (0.0%)
#    Final rows: 3,939
#
# 📂 Processing: EDF.csv
#    Initial rows: 3,012
#    Removed 0 rows (0.0%)
#    Final rows: 3,012
#
# 📂 Processing: EDI.csv
#    Initial rows: 2,548
#    Removed 0 rows (0.0%)
#    Final rows: 2,548
#
# 📂 Processing: EE.csv
#    Initial rows: 168
#    Removed 0 rows (0.0%)
#    Final rows: 168
#
# 📂 Processing: EEA.csv
#    Initial rows: 9,176
#    Removed 0 rows (0.0%)
#    Final rows: 9,176
#
# 📂 Processing: EFR.csv
#    Initial rows: 4,795
#    Removed 0 rows (0.0%)
#    Final rows: 4,795
#
# 📂 Processing: EFT.csv
#    Initial rows: 4,630
#    Removed 0 rows (0.0%)
#    Final rows: 4,630
#
# 📂 Processing: EGF.csv
#    Initial rows: 4,311
#    Removed 0 rows (0.0%)
#    Final rows: 4,311
#
# 📂 Processing: EGL.csv
#    Initial rows: 1,925
#    Removed 986 rows (51.2%)
#    Final rows: 939
#
# 📂 Processing: EGO.csv
#    Initial rows: 5,008
#    Removed 0 rows (0.0%)
#    Final rows: 5,008
#
# 📂 Processing: EGP.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: EHI.csv
#    Initial rows: 4,879
#    Removed 0 rows (0.0%)
#    Final rows: 4,879
#
# 📂 Processing: EIG.csv
#    Initial rows: 3,996
#    Removed 0 rows (0.0%)
#    Final rows: 3,996
#
# 📂 Processing: EIX.csv
#    Initial rows: 12,514
#    Removed 0 rows (0.0%)
#    Final rows: 12,514
#
# 📂 Processing: EL.csv
#    Initial rows: 6,814
#    Removed 0 rows (0.0%)
#    Final rows: 6,814
#
# 📂 Processing: ELP.csv
#    Initial rows: 6,174
#    Removed 0 rows (0.0%)
#    Final rows: 6,174
#
# 📂 Processing: ELS.csv
#    Initial rows: 7,505
#    Removed 0 rows (0.0%)
#    Final rows: 7,505
#
# 📂 Processing: EME.csv
#    Initial rows: 7,032
#    Removed 0 rows (0.0%)
#    Final rows: 7,032
#
# 📂 Processing: EMF.csv
#    Initial rows: 9,022
#    Removed 0 rows (0.0%)
#    Final rows: 9,022
#
# 📂 Processing: EMN.csv
#    Initial rows: 7,302
#    Removed 0 rows (0.0%)
#    Final rows: 7,302
#
# 📂 Processing: EMO.csv
#    Initial rows: 2,895
#    Removed 0 rows (0.0%)
#    Final rows: 2,895
#
# 📂 Processing: EMR.csv
#    Initial rows: 12,744
#    Removed 0 rows (0.0%)
#    Final rows: 12,744
#
# 📂 Processing: ENVA.csv
#    Initial rows: 2,034
#    Removed 0 rows (0.0%)
#    Final rows: 2,034
#
# 📂 Processing: EOD.csv
#    Initial rows: 3,957
#    Removed 0 rows (0.0%)
#    Final rows: 3,957
#
# 📂 Processing: EOG.csv
#    Initial rows: 8,363
#    Removed 0 rows (0.0%)
#    Final rows: 8,363
#
# 📂 Processing: EOS.csv
#    Initial rows: 4,501
#    Removed 0 rows (0.0%)
#    Final rows: 4,501
#
# 📂 Processing: EPAM.csv
#    Initial rows: 2,730
#    Removed 0 rows (0.0%)
#    Final rows: 2,730
#
# 📂 Processing: EPD.csv
#    Initial rows: 6,136
#    Removed 0 rows (0.0%)
#    Final rows: 6,136
#
# 📂 Processing: EPR-PC.csv
#    Initial rows: 4,020
#    Removed 58 rows (1.4%)
#    Final rows: 3,962
#
# 📂 Processing: EPR-PE.csv
#    Initial rows: 3,699
#    Removed 0 rows (0.0%)
#    Final rows: 3,699
#
# 📂 Processing: EPR.csv
#    Initial rows: 6,308
#    Removed 0 rows (0.0%)
#    Final rows: 6,308
#
# 📂 Processing: EQS.csv
#    Initial rows: 7,620
#    Removed 0 rows (0.0%)
#    Final rows: 7,620
#
# 📂 Processing: ESI.csv
#    Initial rows: 2,302
#    Removed 0 rows (0.0%)
#    Final rows: 2,302
#
# 📂 Processing: ESNT.csv
#    Initial rows: 2,295
#    Removed 0 rows (0.0%)
#    Final rows: 2,295
#
# 📂 Processing: ESRT.csv
#    Initial rows: 2,316
#    Removed 0 rows (0.0%)
#    Final rows: 2,316
#
# 📂 Processing: ESS.csv
#    Initial rows: 7,182
#    Removed 0 rows (0.0%)
#    Final rows: 7,182
#
# 📂 Processing: ETN.csv
#    Initial rows: 12,744
#    Removed 0 rows (0.0%)
#    Final rows: 12,744
#
# 📂 Processing: ETP.csv
#    Initial rows: 2,109
#    Removed 42 rows (2.0%)
#    Final rows: 2,067
#
# 📂 Processing: ETX.csv
#    Initial rows: 2,448
#    Removed 0 rows (0.0%)
#    Final rows: 2,448
#
# 📂 Processing: EVC.csv
#    Initial rows: 5,627
#    Removed 0 rows (0.0%)
#    Final rows: 5,627
#
# 📂 Processing: EVER.csv
#    Initial rows: 1,123
#    Removed 0 rows (0.0%)
#    Final rows: 1,123
#
# 📂 Processing: EVF.csv
#    Initial rows: 6,071
#    Removed 0 rows (0.0%)
#    Final rows: 6,071
#
# 📂 Processing: EVN.csv
#    Initial rows: 6,010
#    Removed 0 rows (0.0%)
#    Final rows: 6,010
#
# 📂 Processing: EVR.csv
#    Initial rows: 4,112
#    Removed 0 rows (0.0%)
#    Final rows: 4,112
#
# 📂 Processing: EVT.csv
#    Initial rows: 4,837
#    Removed 0 rows (0.0%)
#    Final rows: 4,837
#
# 📂 Processing: EW.csv
#    Initial rows: 5,716
#    Removed 0 rows (0.0%)
#    Final rows: 5,716
#
# 📂 Processing: EXC.csv
#    Initial rows: 12,515
#    Removed 0 rows (0.0%)
#    Final rows: 12,515
#
# 📂 Processing: EXP.csv
#    Initial rows: 7,220
#    Removed 0 rows (0.0%)
#    Final rows: 7,220
#
# 📂 Processing: EXR.csv
#    Initial rows: 4,615
#    Removed 0 rows (0.0%)
#    Final rows: 4,615
#
# 📂 Processing: F.csv
#    Initial rows: 12,744
#    Removed 0 rows (0.0%)
#    Final rows: 12,744
#
# 📂 Processing: FBC.csv
#    Initial rows: 6,448
#    Removed 13 rows (0.2%)
#    Final rows: 6,435
#
# 📂 Processing: FBHS.csv
#    Initial rows: 2,829
#    Removed 0 rows (0.0%)
#    Final rows: 2,829
#
# 📂 Processing: FBP.csv
#    Initial rows: 9,053
#    Removed 0 rows (0.0%)
#    Final rows: 9,053
#
# 📂 Processing: FBR.csv
#    Initial rows: 4,032
#    Removed 993 rows (24.6%)
#    Final rows: 3,039
#
# 📂 Processing: FCB.csv
#    Initial rows: 2,107
#    Removed 995 rows (47.2%)
#    Final rows: 1,112
#
# 📂 Processing: FCF.csv
#    Initial rows: 7,685
#    Removed 0 rows (0.0%)
#    Final rows: 7,685
#
# 📂 Processing: FCN.csv
#    Initial rows: 6,695
#    Removed 0 rows (0.0%)
#    Final rows: 6,695
#
# 📂 Processing: FCT.csv
#    Initial rows: 4,670
#    Removed 0 rows (0.0%)
#    Final rows: 4,670
#
# 📂 Processing: FDP.csv
#    Initial rows: 6,325
#    Removed 0 rows (0.0%)
#    Final rows: 6,325
#
# 📂 Processing: FDS.csv
#    Initial rows: 6,660
#    Removed 0 rows (0.0%)
#    Final rows: 6,660
#
# 📂 Processing: FEI.csv
#    Initial rows: 2,528
#    Removed 0 rows (0.0%)
#    Final rows: 2,528
#
# 📂 Processing: FEO.csv
#    Initial rows: 3,510
#    Removed 0 rows (0.0%)
#    Final rows: 3,510
#
# 📂 Processing: FET.csv
#    Initial rows: 2,686
#    Removed 0 rows (0.0%)
#    Final rows: 2,686
#
# 📂 Processing: FF.csv
#    Initial rows: 2,952
#    Removed 0 rows (0.0%)
#    Final rows: 2,952
#
# 📂 Processing: FFA.csv
#    Initial rows: 4,606
#    Removed 0 rows (0.0%)
#    Final rows: 4,606
#
# 📂 Processing: FFC.csv
#    Initial rows: 5,003
#    Removed 0 rows (0.0%)
#    Final rows: 5,003
#
# 📂 Processing: FGB.csv
#    Initial rows: 3,916
#    Removed 0 rows (0.0%)
#    Final rows: 3,916
#
# 📂 Processing: FGL.csv
#    Initial rows: 728
#    Removed 727 rows (99.9%)
#    Final rows: 1
#
# 📂 Processing: FHN.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: FIF.csv
#    Initial rows: 2,821
#    Removed 0 rows (0.0%)
#    Final rows: 2,821
#
# 📂 Processing: FIG.csv
#    Initial rows: 145
#    Removed 0 rows (0.0%)
#    Final rows: 145
#
# 📂 Processing: FIS.csv
#    Initial rows: 5,405
#    Removed 0 rows (0.0%)
#    Final rows: 5,405
#
# 📂 Processing: FIX.csv
#    Initial rows: 6,408
#    Removed 0 rows (0.0%)
#    Final rows: 6,408
#
# 📂 Processing: FL.csv
#    Initial rows: 13,356
#    Removed 0 rows (0.0%)
#    Final rows: 13,356
#
# 📂 Processing: FLC.csv
#    Initial rows: 4,858
#    Removed 0 rows (0.0%)
#    Final rows: 4,858
#
# 📂 Processing: FLO.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: FLT.csv
#    Initial rows: 3,019
#    Removed 0 rows (0.0%)
#    Final rows: 3,019
#
# 📂 Processing: FMN.csv
#    Initial rows: 5,029
#    Removed 0 rows (0.0%)
#    Final rows: 5,029
#
# 📂 Processing: FMS.csv
#    Initial rows: 6,605
#    Removed 0 rows (0.0%)
#    Final rows: 6,605
#
# 📂 Processing: FMX.csv
#    Initial rows: 6,190
#    Removed 0 rows (0.0%)
#    Final rows: 6,190
#
# 📂 Processing: FMY.csv
#    Initial rows: 4,417
#    Removed 0 rows (0.0%)
#    Final rows: 4,417
#
# 📂 Processing: FNF.csv
#    Initial rows: 4,320
#    Removed 0 rows (0.0%)
#    Final rows: 4,320
#
# 📂 Processing: FOR.csv
#    Initial rows: 3,776
#    Removed 0 rows (0.0%)
#    Final rows: 3,776
#
# 📂 Processing: FPF.csv
#    Initial rows: 2,406
#    Removed 0 rows (0.0%)
#    Final rows: 2,406
#
# 📂 Processing: FPL.csv
#    Initial rows: 2,195
#    Removed 0 rows (0.0%)
#    Final rows: 2,195
#
# 📂 Processing: FPRUF.csv
#    Initial rows: 2,317
#    Removed 0 rows (0.0%)
#    Final rows: 2,317
#
# 📂 Processing: FPT.csv
#    Initial rows: 3,226
#    Removed 206 rows (6.4%)
#    Final rows: 3,020
#
# 📂 Processing: FR.csv
#    Initial rows: 7,169
#    Removed 0 rows (0.0%)
#    Final rows: 7,169
#
# 📂 Processing: FRA.csv
#    Initial rows: 4,814
#    Removed 0 rows (0.0%)
#    Final rows: 4,814
#
# 📂 Processing: FRO.csv
#    Initial rows: 5,373
#    Removed 0 rows (0.0%)
#    Final rows: 5,373
#
# 📂 Processing: FRT.csv
#    Initial rows: 12,514
#    Removed 0 rows (0.0%)
#    Final rows: 12,514
#
# 📂 Processing: FSD.csv
#    Initial rows: 3,074
#    Removed 0 rows (0.0%)
#    Final rows: 3,074
#
# 📂 Processing: FSM.csv
#    Initial rows: 4,012
#    Removed 0 rows (0.0%)
#    Final rows: 4,012
#
# 📂 Processing: FSS.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: FT.csv
#    Initial rows: 8,622
#    Removed 0 rows (0.0%)
#    Final rows: 8,622
#
# 📂 Processing: FTK.csv
#    Initial rows: 4,376
#    Removed 0 rows (0.0%)
#    Final rows: 4,376
#
# 📂 Processing: FUL.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: FUN.csv
#    Initial rows: 8,983
#    Removed 0 rows (0.0%)
#    Final rows: 8,983
#
# 📂 Processing: G.csv
#    Initial rows: 3,869
#    Removed 0 rows (0.0%)
#    Final rows: 3,869
#
# 📂 Processing: GAB.csv
#    Initial rows: 9,157
#    Removed 0 rows (0.0%)
#    Final rows: 9,157
#
# 📂 Processing: GAIN.csv
#    Initial rows: 4,399
#    Removed 0 rows (0.0%)
#    Final rows: 4,399
#
# 📂 Processing: GAM.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: GBX.csv
#    Initial rows: 7,156
#    Removed 0 rows (0.0%)
#    Final rows: 7,156
#
# 📂 Processing: GCH.csv
#    Initial rows: 3,340
#    Removed 3,141 rows (94.0%)
#    Final rows: 199
#
# 📂 Processing: GCV.csv
#    Initial rows: 6,975
#    Removed 0 rows (0.0%)
#    Final rows: 6,975
#
# 📂 Processing: GD.csv
#    Initial rows: 13,356
#    Removed 0 rows (0.0%)
#    Final rows: 13,356
#
# 📂 Processing: GDO.csv
#    Initial rows: 3,285
#    Removed 0 rows (0.0%)
#    Final rows: 3,285
#
# 📂 Processing: GDV.csv
#    Initial rows: 4,795
#    Removed 0 rows (0.0%)
#    Final rows: 4,795
#
# 📂 Processing: GE.csv
#    Initial rows: 13,356
#    Removed 0 rows (0.0%)
#    Final rows: 13,356
#
# 📂 Processing: GEL.csv
#    Initial rows: 6,554
#    Removed 0 rows (0.0%)
#    Final rows: 6,554
#
# 📂 Processing: GER.csv
#    Initial rows: 2,068
#    Removed 0 rows (0.0%)
#    Final rows: 2,068
#
# 📂 Processing: GF.csv
#    Initial rows: 8,285
#    Removed 0 rows (0.0%)
#    Final rows: 8,285
#
# 📂 Processing: GGE.csv
#    Initial rows: 3,709
#    Removed 0 rows (0.0%)
#    Final rows: 3,709
#
# 📂 Processing: GGZ.csv
#    Initial rows: 2,142
#    Removed 0 rows (0.0%)
#    Final rows: 2,142
#
# 📂 Processing: GHC.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: GHI.csv
#    Initial rows: 9,251
#    Removed 0 rows (0.0%)
#    Final rows: 9,251
#
# 📂 Processing: GHY.csv
#    Initial rows: 2,510
#    Removed 0 rows (0.0%)
#    Final rows: 2,510
#
# 📂 Processing: GIM.csv
#    Initial rows: 8,755
#    Removed 0 rows (0.0%)
#    Final rows: 8,755
#
# 📂 Processing: GIS.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: GJS.csv
#    Initial rows: 4,185
#    Removed 0 rows (0.0%)
#    Final rows: 4,185
#
# 📂 Processing: GLF.csv
#    Initial rows: 1,275
#    Removed 1,024 rows (80.3%)
#    Final rows: 251
#
# 📂 Processing: GLOB.csv
#    Initial rows: 2,117
#    Removed 0 rows (0.0%)
#    Final rows: 2,117
#
# 📂 Processing: GLW.csv
#    Initial rows: 10,325
#    Removed 0 rows (0.0%)
#    Final rows: 10,325
#
# 📂 Processing: GM.csv
#    Initial rows: 3,037
#    Removed 0 rows (0.0%)
#    Final rows: 3,037
#
# 📂 Processing: GMED.csv
#    Initial rows: 2,607
#    Removed 0 rows (0.0%)
#    Final rows: 2,607
#
# 📂 Processing: GNE.csv
#    Initial rows: 2,801
#    Removed 0 rows (0.0%)
#    Final rows: 2,801
#
# 📂 Processing: GNRC.csv
#    Initial rows: 3,232
#    Removed 0 rows (0.0%)
#    Final rows: 3,232
#
# 📂 Processing: GNT.csv
#    Initial rows: 2,990
#    Removed 0 rows (0.0%)
#    Final rows: 2,990
#
# 📂 Processing: GNW.csv
#    Initial rows: 4,671
#    Removed 0 rows (0.0%)
#    Final rows: 4,671
#
# 📂 Processing: GOF.csv
#    Initial rows: 3,873
#    Removed 0 rows (0.0%)
#    Final rows: 3,873
#
# 📂 Processing: GPC.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: GPI.csv
#    Initial rows: 6,321
#    Removed 0 rows (0.0%)
#    Final rows: 6,321
#
# 📂 Processing: GPK.csv
#    Initial rows: 7,557
#    Removed 0 rows (0.0%)
#    Final rows: 7,557
#
# 📂 Processing: GPN.csv
#    Initial rows: 5,513
#    Removed 0 rows (0.0%)
#    Final rows: 5,513
#
# 📂 Processing: GPT.csv
#    Initial rows: 2,409
#    Removed 1,051 rows (43.6%)
#    Final rows: 1,358
#
# 📂 Processing: GRR.csv
#    Initial rows: 3,340
#    Removed 3,141 rows (94.0%)
#    Final rows: 199
#
# 📂 Processing: GRX.csv
#    Initial rows: 3,900
#    Removed 0 rows (0.0%)
#    Final rows: 3,900
#
# 📂 Processing: GS-PJ.csv
#    Initial rows: 2,430
#    Removed 0 rows (0.0%)
#    Final rows: 2,430
#
# 📂 Processing: GSK.csv
#    Initial rows: 10,769
#    Removed 0 rows (0.0%)
#    Final rows: 10,769
#
# 📂 Processing: GSL.csv
#    Initial rows: 3,607
#    Removed 0 rows (0.0%)
#    Final rows: 3,607
#
# 📂 Processing: GTN-A.csv
#    Initial rows: 7,490
#    Removed 0 rows (0.0%)
#    Final rows: 7,490
#
# 📂 Processing: GUT.csv
#    Initial rows: 5,896
#    Removed 0 rows (0.0%)
#    Final rows: 5,896
#
# 📂 Processing: GVA.csv
#    Initial rows: 8,226
#    Removed 0 rows (0.0%)
#    Final rows: 8,226
#
# 📂 Processing: GWRE.csv
#    Initial rows: 2,740
#    Removed 0 rows (0.0%)
#    Final rows: 2,740
#
# 📂 Processing: GWW.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: GXP.csv
#    Initial rows: 12,743
#    Removed 1,277 rows (10.0%)
#    Final rows: 11,466
#
# 📂 Processing: HAL.csv
#    Initial rows: 12,744
#    Removed 0 rows (0.0%)
#    Final rows: 12,744
#
# 📂 Processing: HASI.csv
#    Initial rows: 2,432
#    Removed 0 rows (0.0%)
#    Final rows: 2,432
#
# 📂 Processing: HDB.csv
#    Initial rows: 5,384
#    Removed 0 rows (0.0%)
#    Final rows: 5,384
#
# 📂 Processing: HE.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: HEP.csv
#    Initial rows: 4,642
#    Removed 0 rows (0.0%)
#    Final rows: 4,642
#
# 📂 Processing: HEQ.csv
#    Initial rows: 2,906
#    Removed 0 rows (0.0%)
#    Final rows: 2,906
#
# 📂 Processing: HIE.csv
#    Initial rows: 2,025
#    Removed 0 rows (0.0%)
#    Final rows: 2,025
#
# 📂 Processing: HIG.csv
#    Initial rows: 6,795
#    Removed 0 rows (0.0%)
#    Final rows: 6,795
#
# 📂 Processing: HII.csv
#    Initial rows: 2,953
#    Removed 0 rows (0.0%)
#    Final rows: 2,953
#
# 📂 Processing: HIL.csv
#    Initial rows: 4,617
#    Removed 0 rows (0.0%)
#    Final rows: 4,617
#
# 📂 Processing: HIO.csv
#    Initial rows: 7,321
#    Removed 0 rows (0.0%)
#    Final rows: 7,321
#
# 📂 Processing: HIVE.csv
#    Initial rows: 2,986
#    Removed 0 rows (0.0%)
#    Final rows: 2,986
#
# 📂 Processing: HIW.csv
#    Initial rows: 7,181
#    Removed 0 rows (0.0%)
#    Final rows: 7,181
#
# 📂 Processing: HIX.csv
#    Initial rows: 6,181
#    Removed 0 rows (0.0%)
#    Final rows: 6,181
#
# 📂 Processing: HL.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: HLF.csv
#    Initial rows: 4,529
#    Removed 0 rows (0.0%)
#    Final rows: 4,529
#
# 📂 Processing: HLT.csv
#    Initial rows: 2,266
#    Removed 0 rows (0.0%)
#    Final rows: 2,266
#
# 📂 Processing: HLX.csv
#    Initial rows: 6,406
#    Removed 0 rows (0.0%)
#    Final rows: 6,406
#
# 📂 Processing: HMC.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: HMN.csv
#    Initial rows: 7,827
#    Removed 0 rows (0.0%)
#    Final rows: 7,827
#
# 📂 Processing: HMY.csv
#    Initial rows: 7,196
#    Removed 0 rows (0.0%)
#    Final rows: 7,196
#
# 📂 Processing: HON.csv
#    Initial rows: 13,356
#    Removed 0 rows (0.0%)
#    Final rows: 13,356
#
# 📂 Processing: HOT.csv
#    Initial rows: 2,001
#    Removed 1,499 rows (74.9%)
#    Final rows: 502
#
# 📂 Processing: HOV.csv
#    Initial rows: 9,899
#    Removed 0 rows (0.0%)
#    Final rows: 9,899
#
# 📂 Processing: HP.csv
#    Initial rows: 10,630
#    Removed 0 rows (0.0%)
#    Final rows: 10,630
#
# 📂 Processing: HPF.csv
#    Initial rows: 5,046
#    Removed 0 rows (0.0%)
#    Final rows: 5,046
#
# 📂 Processing: HPP.csv
#    Initial rows: 3,140
#    Removed 0 rows (0.0%)
#    Final rows: 3,140
#
# 📂 Processing: HPS.csv
#    Initial rows: 4,908
#    Removed 0 rows (0.0%)
#    Final rows: 4,908
#
# 📂 Processing: HQH.csv
#    Initial rows: 8,983
#    Removed 0 rows (0.0%)
#    Final rows: 8,983
#
# 📂 Processing: HQL.csv
#    Initial rows: 7,712
#    Removed 0 rows (0.0%)
#    Final rows: 7,712
#
# 📂 Processing: HR.csv
#    Initial rows: 2,648
#    Removed 0 rows (0.0%)
#    Final rows: 2,648
#
# 📂 Processing: HRL.csv
# ...
#    Final rows: 2,559
#
# 📂 Processing: ST.csv
#    Initial rows: 3,213
#    Removed 0 rows (0.0%)
#    Final rows: 3,213
#
# 📂 Processing: STAG.csv
#    Initial rows: 2,935
#    Removed 0 rows (0.0%)
#    Final rows: 2,935
#
# 📂 Processing: STC.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: STM.csv
#    Initial rows: 7,053
#    Removed 0 rows (0.0%)
#    Final rows: 7,053
#
# 📂 Processing: STNG.csv
#    Initial rows: 3,199
#    Removed 0 rows (0.0%)
#    Final rows: 3,199
#
# 📂 Processing: STOR.csv
#    Initial rows: 2,031
#    Removed 0 rows (0.0%)
#    Final rows: 2,031
#
# 📂 Processing: STRI.csv
#    Initial rows: 3,296
#    Removed 0 rows (0.0%)
#    Final rows: 3,296
#
# 📂 Processing: STT.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: STWD.csv
#    Initial rows: 3,358
#    Removed 0 rows (0.0%)
#    Final rows: 3,358
#
# 📂 Processing: STZ-B.csv
#    Initial rows: 12,558
#    Removed 1,281 rows (10.2%)
#    Final rows: 11,277
#
# 📂 Processing: SU.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: SUI.csv
#    Initial rows: 7,305
#    Removed 0 rows (0.0%)
#    Final rows: 7,305
#
# 📂 Processing: SUP.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: SVMLF.csv
#    Initial rows: 85
#    Removed 0 rows (0.0%)
#    Final rows: 85
#
# 📂 Processing: SWK.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: SWN.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: SWZ.csv
#    Initial rows: 8,901
#    Removed 0 rows (0.0%)
#    Final rows: 8,901
#
# 📂 Processing: SXC.csv
#    Initial rows: 2,869
#    Removed 0 rows (0.0%)
#    Final rows: 2,869
#
# 📂 Processing: SXI.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: SXT.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: SYF.csv
#    Initial rows: 2,108
#    Removed 0 rows (0.0%)
#    Final rows: 2,108
#
# 📂 Processing: T.csv
#    Initial rows: 9,846
#    Removed 0 rows (0.0%)
#    Final rows: 9,846
#
# 📂 Processing: TA.csv
#    Initial rows: 3,995
#    Removed 0 rows (0.0%)
#    Final rows: 3,995
#
# 📂 Processing: TAC.csv
#    Initial rows: 5,377
#    Removed 0 rows (0.0%)
#    Final rows: 5,377
#
# 📂 Processing: TAP.csv
#    Initial rows: 11,981
#    Removed 0 rows (0.0%)
#    Final rows: 11,981
#
# 📂 Processing: TARO.csv
#    Initial rows: 10,148
#    Removed 0 rows (0.0%)
#    Final rows: 10,148
#
# 📂 Processing: TCI.csv
#    Initial rows: 9,520
#    Removed 0 rows (0.0%)
#    Final rows: 9,520
#
# 📂 Processing: TCPTF.csv
#    Initial rows: 658
#    Removed 203 rows (30.9%)
#    Final rows: 455
#
# 📂 Processing: TDF.csv
#    Initial rows: 7,108
#    Removed 0 rows (0.0%)
#    Final rows: 7,108
#
# 📂 Processing: TDG.csv
#    Initial rows: 4,217
#    Removed 0 rows (0.0%)
#    Final rows: 4,217
#
# 📂 Processing: TDS.csv
#    Initial rows: 10,336
#    Removed 0 rows (0.0%)
#    Final rows: 10,336
#
# 📂 Processing: TDY.csv
#    Initial rows: 5,801
#    Removed 0 rows (0.0%)
#    Final rows: 5,801
#
# 📂 Processing: TEI.csv
#    Initial rows: 7,359
#    Removed 0 rows (0.0%)
#    Final rows: 7,359
#
# 📂 Processing: TEO.csv
#    Initial rows: 7,052
#    Removed 0 rows (0.0%)
#    Final rows: 7,052
#
# 📂 Processing: TEUFF.csv
#    Initial rows: 2,935
#    Removed 0 rows (0.0%)
#    Final rows: 2,935
#
# 📂 Processing: TEVA.csv
#    Initial rows: 10,294
#    Removed 0 rows (0.0%)
#    Final rows: 10,294
#
# 📂 Processing: TGH.csv
#    Initial rows: 3,821
#    Removed 0 rows (0.0%)
#    Final rows: 3,821
#
# 📂 Processing: TGI.csv
#    Initial rows: 6,577
#    Removed 0 rows (0.0%)
#    Final rows: 6,577
#
# 📂 Processing: TGS.csv
#    Initial rows: 7,067
#    Removed 0 rows (0.0%)
#    Final rows: 7,067
#
# 📂 Processing: THG.csv
#    Initial rows: 6,841
#    Removed 0 rows (0.0%)
#    Final rows: 6,841
#
# 📂 Processing: THLEF.csv
#    Initial rows: 4,310
#    Removed 0 rows (0.0%)
#    Final rows: 4,310
#
# 📂 Processing: THO.csv
#    Initial rows: 9,813
#    Removed 0 rows (0.0%)
#    Final rows: 9,813
#
# 📂 Processing: THQ.csv
#    Initial rows: 2,110
#    Removed 0 rows (0.0%)
#    Final rows: 2,110
#
# 📂 Processing: THR.csv
#    Initial rows: 2,922
#    Removed 0 rows (0.0%)
#    Final rows: 2,922
#
# 📂 Processing: THS.csv
#    Initial rows: 4,396
#    Removed 0 rows (0.0%)
#    Final rows: 4,396
#
# 📂 Processing: TKC.csv
#    Initial rows: 5,643
#    Removed 0 rows (0.0%)
#    Final rows: 5,643
#
# 📂 Processing: TLK.csv
#    Initial rows: 6,817
#    Removed 0 rows (0.0%)
#    Final rows: 6,817
#
# 📂 Processing: TMHC.csv
#    Initial rows: 2,438
#    Removed 0 rows (0.0%)
#    Final rows: 2,438
#
# 📂 Processing: TMO.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: TMST.csv
#    Initial rows: 2,137
#    Removed 0 rows (0.0%)
#    Final rows: 2,137
#
# 📂 Processing: TNC.csv
#    Initial rows: 12,563
#    Removed 0 rows (0.0%)
#    Final rows: 12,563
#
# 📂 Processing: TNH.csv
#    Initial rows: 7,820
#    Removed 1,195 rows (15.3%)
#    Final rows: 6,625
#
# 📂 Processing: TNK.csv
#    Initial rows: 3,776
#    Removed 0 rows (0.0%)
#    Final rows: 3,776
#
# 📂 Processing: TNP.csv
#    Initial rows: 5,232
#    Removed 0 rows (0.0%)
#    Final rows: 5,232
#
# 📂 Processing: TOL.csv
#    Initial rows: 9,184
#    Removed 0 rows (0.0%)
#    Final rows: 9,184
#
# 📂 Processing: TPC.csv
#    Initial rows: 12,514
#    Removed 0 rows (0.0%)
#    Final rows: 12,514
#
# 📂 Processing: TPL.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: TPPPF.csv
#    Initial rows: 6,794
#    Removed 230 rows (3.4%)
#    Final rows: 6,564
#
# 📂 Processing: TPVG.csv
#    Initial rows: 2,210
#    Removed 0 rows (0.0%)
#    Final rows: 2,210
#
# 📂 Processing: TPX.csv
#    Initial rows: 4,779
#    Removed 0 rows (0.0%)
#    Final rows: 4,779
#
# 📂 Processing: TPZ.csv
#    Initial rows: 3,368
#    Removed 0 rows (0.0%)
#    Final rows: 3,368
#
# 📂 Processing: TR.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: TRC.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: TRI.csv
#    Initial rows: 5,163
#    Removed 0 rows (0.0%)
#    Final rows: 5,163
#
# 📂 Processing: TRMR.csv
#    Initial rows: 375
#    Removed 0 rows (0.0%)
#    Final rows: 375
#
# 📂 Processing: TRN.csv
#    Initial rows: 12,514
#    Removed 0 rows (0.0%)
#    Final rows: 12,514
#
# 📂 Processing: TRNO.csv
#    Initial rows: 3,233
#    Removed 0 rows (0.0%)
#    Final rows: 3,233
#
# 📂 Processing: TRQ.csv
#    Initial rows: 4,800
#    Removed 0 rows (0.0%)
#    Final rows: 4,800
#
# 📂 Processing: TRV.csv
#    Initial rows: 11,871
#    Removed 0 rows (0.0%)
#    Final rows: 11,871
#
# 📂 Processing: TSE.csv
#    Initial rows: 2,142
#    Removed 0 rows (0.0%)
#    Final rows: 2,142
#
# 📂 Processing: TSI.csv
#    Initial rows: 9,022
#    Removed 0 rows (0.0%)
#    Final rows: 9,022
#
# 📂 Processing: TSLX.csv
#    Initial rows: 2,199
#    Removed 0 rows (0.0%)
#    Final rows: 2,199
#
# 📂 Processing: TSM.csv
#    Initial rows: 6,336
#    Removed 0 rows (0.0%)
#    Final rows: 6,336
#
# 📂 Processing: TSQ.csv
#    Initial rows: 2,113
#    Removed 0 rows (0.0%)
#    Final rows: 2,113
#
# 📂 Processing: TTM.csv
#    Initial rows: 4,586
#    Removed 0 rows (0.0%)
#    Final rows: 4,586
#
# 📂 Processing: TTP.csv
#    Initial rows: 2,800
#    Removed 0 rows (0.0%)
#    Final rows: 2,800
#
# 📂 Processing: TUP.csv
#    Initial rows: 6,696
#    Removed 0 rows (0.0%)
#    Final rows: 6,696
#
# 📂 Processing: TV.csv
#    Initial rows: 7,302
#    Removed 0 rows (0.0%)
#    Final rows: 7,302
#
# 📂 Processing: TVE.csv
#    Initial rows: 5,932
#    Removed 0 rows (0.0%)
#    Final rows: 5,932
#
# 📂 Processing: TVPT.csv
#    Initial rows: 2,069
#    Removed 912 rows (44.1%)
#    Final rows: 1,157
#
# 📂 Processing: TW.csv
#    Initial rows: 931
#    Removed 0 rows (0.0%)
#    Final rows: 931
#
# 📂 Processing: TWI.csv
#    Initial rows: 7,446
#    Removed 0 rows (0.0%)
#    Final rows: 7,446
#
# 📂 Processing: TWO.csv
#    Initial rows: 3,302
#    Removed 0 rows (0.0%)
#    Final rows: 3,302
#
# 📂 Processing: TY.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: TYG.csv
#    Initial rows: 4,734
#    Removed 0 rows (0.0%)
#    Final rows: 4,734
#
# 📂 Processing: UAL.csv
#    Initial rows: 4,243
#    Removed 0 rows (0.0%)
#    Final rows: 4,243
#
# 📂 Processing: UBA.csv
#    Initial rows: 6,122
#    Removed 0 rows (0.0%)
#    Final rows: 6,122
#
# 📂 Processing: UHS.csv
#    Initial rows: 10,447
#    Removed 0 rows (0.0%)
#    Final rows: 10,447
#
# 📂 Processing: UHT.csv
#    Initial rows: 9,064
#    Removed 0 rows (0.0%)
#    Final rows: 9,064
#
# 📂 Processing: UL.csv
#    Initial rows: 10,772
#    Removed 0 rows (0.0%)
#    Final rows: 10,772
#
# 📂 Processing: UMC.csv
#    Initial rows: 5,594
#    Removed 0 rows (0.0%)
#    Final rows: 5,594
#
# 📂 Processing: UMH.csv
#    Initial rows: 9,531
#    Removed 0 rows (0.0%)
#    Final rows: 9,531
#
# 📂 Processing: UNH.csv
#    Initial rows: 9,617
#    Removed 0 rows (0.0%)
#    Final rows: 9,617
#
# 📂 Processing: UNM.csv
#    Initial rows: 9,098
#    Removed 0 rows (0.0%)
#    Final rows: 9,098
#
# 📂 Processing: UPS.csv
#    Initial rows: 5,810
#    Removed 0 rows (0.0%)
#    Final rows: 5,810
#
# 📂 Processing: URI.csv
#    Initial rows: 6,287
#    Removed 0 rows (0.0%)
#    Final rows: 6,287
#
# 📂 Processing: USM.csv
#    Initial rows: 8,722
#    Removed 0 rows (0.0%)
#    Final rows: 8,722
#
# 📂 Processing: USNA.csv
#    Initial rows: 7,226
#    Removed 0 rows (0.0%)
#    Final rows: 7,226
#
# 📂 Processing: USPH.csv
#    Initial rows: 7,693
#    Removed 0 rows (0.0%)
#    Final rows: 7,693
#
# 📂 Processing: UTF.csv
#    Initial rows: 4,712
#    Removed 0 rows (0.0%)
#    Final rows: 4,712
#
# 📂 Processing: UTI.csv
#    Initial rows: 4,779
#    Removed 0 rows (0.0%)
#    Final rows: 4,779
#
# 📂 Processing: V.csv
#    Initial rows: 3,711
#    Removed 0 rows (0.0%)
#    Final rows: 3,711
#
# 📂 Processing: VAC.csv
#    Initial rows: 2,792
#    Removed 0 rows (0.0%)
#    Final rows: 2,792
#
# 📂 Processing: VBF.csv
#    Initial rows: 10,079
#    Removed 0 rows (0.0%)
#    Final rows: 10,079
#
# 📂 Processing: VCV.csv
#    Initial rows: 7,432
#    Removed 0 rows (0.0%)
#    Final rows: 7,432
#
# 📂 Processing: VEEV.csv
#    Initial rows: 2,306
#    Removed 0 rows (0.0%)
#    Final rows: 2,306
#
# 📂 Processing: VET.csv
#    Initial rows: 3,084
#    Removed 0 rows (0.0%)
#    Final rows: 3,084
#
# 📂 Processing: VGI.csv
#    Initial rows: 2,719
#    Removed 0 rows (0.0%)
#    Final rows: 2,719
#
# 📂 Processing: VGM.csv
#    Initial rows: 7,763
#    Removed 0 rows (0.0%)
#    Final rows: 7,763
#
# 📂 Processing: VGR.csv
#    Initial rows: 8,866
#    Removed 0 rows (0.0%)
#    Final rows: 8,866
#
# 📂 Processing: VIV.csv
#    Initial rows: 6,058
#    Removed 0 rows (0.0%)
#    Final rows: 6,058
#
# 📂 Processing: VKQ.csv
#    Initial rows: 7,823
#    Removed 0 rows (0.0%)
#    Final rows: 7,823
#
# 📂 Processing: VLT.csv
#    Initial rows: 8,478
#    Removed 0 rows (0.0%)
#    Final rows: 8,478
#
# 📂 Processing: VLY.csv
#    Initial rows: 8,245
#    Removed 0 rows (0.0%)
#    Final rows: 8,245
#
# 📂 Processing: VMC.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: VMI.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: VMO.csv
#    Initial rows: 7,690
#    Removed 0 rows (0.0%)
#    Final rows: 7,690
#
# 📂 Processing: VNCE.csv
#    Initial rows: 2,279
#    Removed 0 rows (0.0%)
#    Final rows: 2,279
#
# 📂 Processing: VOYA.csv
#    Initial rows: 2,422
#    Removed 0 rows (0.0%)
#    Final rows: 2,422
#
# 📂 Processing: VPG.csv
#    Initial rows: 3,141
#    Removed 0 rows (0.0%)
#    Final rows: 3,141
#
# 📂 Processing: VPV.csv
#    Initial rows: 7,432
#    Removed 0 rows (0.0%)
#    Final rows: 7,432
#
# 📂 Processing: VR.csv
#    Initial rows: 158
#    Removed 0 rows (0.0%)
#    Final rows: 158
#
# 📂 Processing: VSH.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: VTN.csv
#    Initial rows: 7,704
#    Removed 0 rows (0.0%)
#    Final rows: 7,704
#
# 📂 Processing: VULC.csv
#    Initial rows: 12,739
#    Removed 1,135 rows (8.9%)
#    Final rows: 11,604
#
# 📂 Processing: VVR.csv
#    Initial rows: 6,159
#    Removed 0 rows (0.0%)
#    Final rows: 6,159
#
# 📂 Processing: VZ.csv
#    Initial rows: 9,846
#    Removed 0 rows (0.0%)
#    Final rows: 9,846
#
# 📂 Processing: WAB.csv
#    Initial rows: 6,922
#    Removed 0 rows (0.0%)
#    Final rows: 6,922
#
# 📂 Processing: WAL.csv
#    Initial rows: 4,393
#    Removed 0 rows (0.0%)
#    Final rows: 4,393
#
# 📂 Processing: WBS.csv
#    Initial rows: 9,073
#    Removed 0 rows (0.0%)
#    Final rows: 9,073
#
# 📂 Processing: WCC.csv
#    Initial rows: 5,937
#    Removed 0 rows (0.0%)
#    Final rows: 5,937
#
# 📂 Processing: WCN.csv
#    Initial rows: 6,181
#    Removed 0 rows (0.0%)
#    Final rows: 6,181
#
# 📂 Processing: WD.csv
#    Initial rows: 3,019
#    Removed 0 rows (0.0%)
#    Final rows: 3,019
#
# 📂 Processing: WES.csv
#    Initial rows: 2,520
#    Removed 0 rows (0.0%)
#    Final rows: 2,520
#
# 📂 Processing: WFC.csv
#    Initial rows: 12,744
#    Removed 0 rows (0.0%)
#    Final rows: 12,744
#
# 📂 Processing: WGL.csv
#    Initial rows: 12,743
#    Removed 1,269 rows (10.0%)
#    Final rows: 11,474
#
# 📂 Processing: WGO.csv
#    Initial rows: 12,564
#    Removed 0 rows (0.0%)
#    Final rows: 12,564
#
# 📂 Processing: WHG.csv
#    Initial rows: 5,162
#    Removed 0 rows (0.0%)
#    Final rows: 5,162
#
# 📂 Processing: WIA.csv
#    Initial rows: 4,836
#    Removed 0 rows (0.0%)
#    Final rows: 4,836
#
# 📂 Processing: WIT.csv
#    Initial rows: 5,572
#    Removed 0 rows (0.0%)
#    Final rows: 5,572
#
# 📂 Processing: WLK.csv
#    Initial rows: 4,617
#    Removed 0 rows (0.0%)
#    Final rows: 4,617
#
# 📂 Processing: WM.csv
#    Initial rows: 8,688
#    Removed 0 rows (0.0%)
#    Final rows: 8,688
#
# 📂 Processing: WMB.csv
#    Initial rows: 10,325
#    Removed 0 rows (0.0%)
#    Final rows: 10,325
#
# 📂 Processing: WMC.csv
#    Initial rows: 2,665
#    Removed 0 rows (0.0%)
#    Final rows: 2,665
#
# 📂 Processing: WMK.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: WMS.csv
#    Initial rows: 2,112
#    Removed 0 rows (0.0%)
#    Final rows: 2,112
#
# 📂 Processing: WNC.csv
#    Initial rows: 7,832
#    Removed 0 rows (0.0%)
#    Final rows: 7,832
#
# 📂 Processing: WNS.csv
#    Initial rows: 4,125
#    Removed 0 rows (0.0%)
#    Final rows: 4,125
#
# 📂 Processing: WOR.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: WPC.csv
#    Initial rows: 6,266
#    Removed 0 rows (0.0%)
#    Final rows: 6,266
#
# 📂 Processing: WPZ.csv
#    Initial rows: 3,116
#    Removed 1,094 rows (35.1%)
#    Final rows: 2,022
#
# 📂 Processing: WRB.csv
#    Initial rows: 12,394
#    Removed 0 rows (0.0%)
#    Final rows: 12,394
#
# 📂 Processing: WRE.csv
#    Initial rows: 12,742
#    Removed 117 rows (0.9%)
#    Final rows: 12,625
#
# 📂 Processing: WSR.csv
#    Initial rows: 3,096
#    Removed 0 rows (0.0%)
#    Final rows: 3,096
#
# 📂 Processing: WST.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: WTI.csv
#    Initial rows: 4,500
#    Removed 0 rows (0.0%)
#    Final rows: 4,500
#
# 📂 Processing: WTM.csv
#    Initial rows: 9,361
#    Removed 0 rows (0.0%)
#    Final rows: 9,361
#
# 📂 Processing: WTS.csv
#    Initial rows: 9,152
#    Removed 0 rows (0.0%)
#    Final rows: 9,152
#
# 📂 Processing: WTW.csv
#    Initial rows: 5,411
#    Removed 0 rows (0.0%)
#    Final rows: 5,411
#
# 📂 Processing: WWE.csv
#    Initial rows: 5,826
#    Removed 0 rows (0.0%)
#    Final rows: 5,826
#
# 📂 Processing: WWW.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: X.csv
#    Initial rows: 7,979
#    Removed 0 rows (0.0%)
#    Final rows: 7,979
#
# 📂 Processing: XHR.csv
#    Initial rows: 1,979
#    Removed 0 rows (0.0%)
#    Final rows: 1,979
#
# 📂 Processing: XIN.csv
#    Initial rows: 3,777
#    Removed 0 rows (0.0%)
#    Final rows: 3,777
#
# 📂 Processing: XPO.csv
#    Initial rows: 4,830
#    Removed 0 rows (0.0%)
#    Final rows: 4,830
#
# 📂 Processing: YPF.csv
#    Initial rows: 7,419
#    Removed 0 rows (0.0%)
#    Final rows: 7,419
#
# 📂 Processing: YUM.csv
#    Initial rows: 6,352
#    Removed 0 rows (0.0%)
#    Final rows: 6,352
#
# 📂 Processing: ZDPY.csv
#    Initial rows: 3,176
#    Removed 0 rows (0.0%)
#    Final rows: 3,176
#
# 📂 Processing: ZION.csv
#    Initial rows: 10,778
#    Removed 0 rows (0.0%)
#    Final rows: 10,778
#
# 📂 Processing: ZNH.csv
#    Initial rows: 6,386
#    Removed 0 rows (0.0%)
#    Final rows: 6,386
#
# 📂 Processing: ZOES.csv
#    Initial rows: 2,184
#    Removed 1,021 rows (46.7%)
#    Final rows: 1,163
#
# ==================================================
# ✅ Processed 1145 files successfully
# ❌ 0 files had errors: []

# %%
if all_clean_dfs:
    final_df = pd.concat(all_clean_dfs, ignore_index=True)
    print(f"\n🎉 Combined DataFrame shape: {final_df.shape}")
    print("Sample data (first 5 rows):")
    display(final_df.head())

    # Save to CSV
    save_path = '/content/cleaned_combined_data_nyse.csv'
    final_df.to_csv(save_path, index=False)

    # Download
    from google.colab import files
    files.download(save_path)
    print(f"\n📥 File downloaded: 'cleaned_combined_data_nyse.csv'")
else:
    print("\n⚠️ No files were processed successfully")
# Out:
# 🎉 Combined DataFrame shape: (6899426, 8)
# Sample data (first 5 rows):
#         Date                Low               Open  Volume               High  \
# 0 2021-03-25  9.520000457763672  9.949999809265137  117100  9.949999809265137
# 1 2021-03-26               9.75  9.850000381469727  158300  9.960000038146973
# 2 2021-03-29                9.5  9.699999809265137   53600  9.902000427246094
# 3 2021-03-30  9.800000190734863  9.800000190734863   52300  9.850000381469727
# 4 2021-03-31               9.75               9.75   78600  9.899999618530273
#
#                Close     Adjusted Close Company Symbol
# 0  9.869999885559082  9.869999885559082            AAC
# 1  9.960000038146973  9.960000038146973            AAC
# 2  9.779999732971191  9.779999732971191            AAC
# 3  9.829999923706055  9.829999923706055            AAC
# 4  9.899999618530273  9.899999618530273            AAC
# 📥 File downloaded: 'cleaned_combined_data_nyse.csv'

# %%
import pandas as pd
import os

from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Load the cleaned CSV files from their respective folders
cleaned_data_folder_1 = '/content/drive/MyDrive/cleaned_data_stock_market/nasdaq/'
cleaned_data_folder_2 = '/content/drive/MyDrive/cleaned_data_stock_market/nyse/'

# Load the cleaned CSV files
df1 = pd.read_csv(os.path.join(cleaned_data_folder_1, 'cleaned_combined_data.csv'))
df2 = pd.read_csv(os.path.join(cleaned_data_folder_2, 'cleaned_combined_data_nyse.csv'))

# Combine the two DataFrames
combined_df = pd.concat([df1, df2], ignore_index=True)
print(f"✅ Combined DataFrame shape: {combined_df.shape}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Combined DataFrame shape: (15521471, 8)

# %%
# Ensure the 'Date' column is in datetime format
combined_df['Date'] = pd.to_datetime(combined_df['Date'], errors='coerce')

# Filter for data after the year 2012
filtered_df = combined_df[combined_df['Date'] >= '2015-01-01']

print(f"🎉 Filtered DataFrame shape (after 2012): {filtered_df.shape}")
print("Sample data (first 5 rows after 2012):")
display(filtered_df.head())
# Out:
# /tmp/ipython-input-10-822600974.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   combined_df['Date'] = pd.to_datetime(combined_df['Date'], errors='coerce')
# 🎉 Filtered DataFrame shape (after 2012): (2908328, 8)
# Sample data (first 5 rows after 2012):
#            Date        Low       Open      Volume       High      Close  \
# 2332 2015-01-02  53.070000  54.279999  10748600.0  54.599998  53.910000
# 2333 2015-01-05  53.340000  54.369999  11565000.0  54.540001  53.880001
# 2334 2015-01-06  52.130001  54.270000  13772200.0  54.430000  53.040001
# 2335 2015-01-07  52.119999  53.380001  10069800.0  53.650002  53.009998
# 2336 2015-01-08  53.250000  53.480000   9672100.0  54.279999  53.660000
#
#       Adjusted Close Company Symbol
# 2332       51.079906            AAL
# 2333       51.051483            AAL
# 2334       50.255581            AAL
# 2335       50.227158            AAL
# 2336       50.843033            AAL

# %%
# Save the filtered DataFrame to a new CSV file
filtered_save_path = '/content/filtered_combined_data_after_2015.csv'
filtered_df.to_csv(filtered_save_path, index=False)

# Download the filtered CSV
from google.colab import files
files.download(filtered_save_path)
print(f"\n📥 Filtered file downloaded: 'filtered_combined_data_after_2015.csv'")
# Out:
# 📥 Filtered file downloaded: 'filtered_combined_data_after_2012.csv'
